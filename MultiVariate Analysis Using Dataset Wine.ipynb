# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

DISPLAY_MAX_ROWS =1000

# %%
data = pd.read_csv("wine.data", header=None)
data.columns = ["V"+str(i) for i in range(1, len(data.columns)+1)] 
X = data.loc[:, "V2":] 
y = data.V1     #Sample Number
data   #Actual Dataset
# Out:
#      V1     V2    V3    V4    V5   V6    V7    V8    V9   V10    V11   V12  \
# 0     1  14.23  1.71  2.43  15.6  127  2.80  3.06  0.28  2.29   5.64  1.04
# 1     1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 2     1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 3     1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 4     1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# ..   ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 173   3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 174   3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 175   3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 176   3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 177   3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#       V13   V14
# 0    3.92  1065
# 1    3.40  1050
# ...

# %%
data.loc[:, "V2":"V4"]   #Columns Used!
# Out:
#         V2    V3    V4
# 0    14.23  1.71  2.43
# 1    13.20  1.78  2.14
# 2    13.16  2.36  2.67
# 3    14.37  1.95  2.50
# 4    13.24  2.59  2.87
# ..     ...   ...   ...
# 173  13.71  5.65  2.45
# 174  13.40  3.91  2.48
# 175  13.27  4.28  2.26
# 176  13.17  2.59  2.37
# 177  14.13  4.10  2.74
#
# [178 rows x 3 columns]

# %%
pd.plotting.scatter_matrix(data.loc[:, "V2":"V4"])
plt.tight_layout()
plt.show()  
#Diagonal Shows the Histogram of two Variables
#Off-Diagonal shows the scatter points

# %%
sns.lmplot("V4", "V5", data, hue="V1", fit_reg=False);

#CONCLUSION - Sample 3 has almost equal concentration of both V5 and V4, whereas sample 2 has lower concentration
#of V4 than compared to V5 and vice versa
# Out:
# /Users/joshuablue/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot("V9", "V14", data, hue="V1", fit_reg=False);

#CONCLUSION - Sample 1 has higher concentration of V14, whereas sample 2 AND 3 has higer concentration
#of V9 than compared to V5 and vice versa
# Out:
# /Users/joshuablue/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = data[["V2","V3","V4", "V6"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));
#CONCLUSION - Shows that V6 has higher Mean and Variance than higer variable

# %%
X.apply(np.mean)
# Out:
# V2      13.000618
# V3       2.336348
# V4       2.366517
# V5      19.494944
# V6      99.741573
# V7       2.295112
# V8       2.029270
# V9       0.361854
# V10      1.590899
# V11      5.058090
# V12      0.957449
# V13      2.611685
# V14    746.893258
# dtype: float64

# %%
X.apply(np.std)
# Out:
# V2       0.809543
# V3       1.114004
# V4       0.273572
# V5       3.330170
# V6      14.242308
# V7       0.624091
# V8       0.996049
# V9       0.124103
# V10      0.570749
# V11      2.311765
# V12      0.227929
# V13      0.707993
# V14    314.021657
# dtype: float64

# %%
corrmat = X.corr()     #Checking correlation of all chemicals
corrmat
# Out:
#            V2        V3        V4        V5        V6        V7        V8  \
# V2   1.000000  0.094397  0.211545 -0.310235  0.270798  0.289101  0.236815
# V3   0.094397  1.000000  0.164045  0.288500 -0.054575 -0.335167 -0.411007
# V4   0.211545  0.164045  1.000000  0.443367  0.286587  0.128980  0.115077
# V5  -0.310235  0.288500  0.443367  1.000000 -0.083333 -0.321113 -0.351370
# V6   0.270798 -0.054575  0.286587 -0.083333  1.000000  0.214401  0.195784
# V7   0.289101 -0.335167  0.128980 -0.321113  0.214401  1.000000  0.864564
# V8   0.236815 -0.411007  0.115077 -0.351370  0.195784  0.864564  1.000000
# V9  -0.155929  0.292977  0.186230  0.361922 -0.256294 -0.449935 -0.537900
# V10  0.136698 -0.220746  0.009652 -0.197327  0.236441  0.612413  0.652692
# V11  0.546364  0.248985  0.258887  0.018732  0.199950 -0.055136 -0.172379
# V12 -0.071747 -0.561296 -0.074667 -0.273955  0.055398  0.433681  0.543479
# V13  0.072343 -0.368710  0.003911 -0.276769  0.066004  0.699949  0.787194
# ...

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_top()

#Visually representing the cprrelation of two variable with Heat Map

# %%
# Principle Component Analysis

# %%
# Linear Discrimination Analysis
